# %%
# !pip install notebook ipykernel
# !python -m ipykernel install --user --name=ck_eval_env --display-name "Python (ck_eval_env)"
# !jupyter notebook
# Out:
# Requirement already satisfied: notebook in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (7.5.0)
# Requirement already satisfied: ipykernel in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (6.31.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.0rc0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from notebook) (4.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from notebook) (6.5.2)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\i n t e l\appdata\local\programs\python\python39\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (8.18.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: psutil>=5.7 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (7.1.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\i n t e l\appdata\local\programs\python\python39\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\i n t e l\appdata\local\programs\python\python39\lib\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (49.2.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (2.0.5)
# Requirement already satisfied: tomli>=1.2.2; python_version < "3.11" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (2.3.0)
# Requirement already satisfied: importlib-metadata>=4.8.3; python_version < "3.10" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (8.7.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (2.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1; os_name == "nt" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.3)
# Requirement already satisfied: overrides>=5.0; python_version < "3.12" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Requirement already satisfied: babel>=2.10 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: decorator in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: exceptiongroup; python_version < "3.11" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: stack-data in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: typing-extensions; python_version < "3.10" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from ipython>=7.23.1->ipykernel) (4.15.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: pywin32>=300; sys_platform == "win32" and platform_python_implementation != "PyPy" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: zipp>=3.20 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.8.3; python_version < "3.10"->jupyterlab<4.6,>=4.5.0rc0->notebook) (3.23.0)
# Requirement already satisfied: idna in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (3.11)
# Requirement already satisfied: certifi in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jinja2>=3.0.3->jupyterlab<4.6,>=4.5.0rc0->notebook) (3.0.3)
# Requirement already satisfied: referencing in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.36.2)
# Requirement already satisfied: rfc3339-validator in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.3)
# Requirement already satisfied: defusedxml in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.27.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: wcwidth in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: h11>=0.16 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8)
# Requirement already satisfied: webencodings in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0; extra == "css" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: cffi>=1.0.1; python_version < "3.14" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser; implementation_name != "PyPy" in c:\users\i n t e l\appdata\roaming\python\python39\site-packages (from cffi>=1.0.1; python_version < "3.14"->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.23)
# WARNING: You are using pip version 20.2.3; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\users\i n t e l\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Installed kernelspec ck_eval_env in C:\Users\I N T E L\AppData\Roaming\jupyter\kernels\ck_eval_env
# ^C

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 10
#       8 import torch.nn as nn
#       9 from torch.utils.data import Dataset, DataLoader
# ---> 10 from torchvision import models, transforms
#      12 from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\convnext.py:10
#       7 from torch.nn import functional as F
#       9 from ..ops.misc import Conv2dNormActivation, Permute
# ---> 10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..transforms._presets import ImageClassification
#      12 from ..utils import _log_api_usage_once
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\ops\__init__.py:23
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\ops\poolers.py:10
#       7 from torchvision.ops.boxes import box_area
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      13 # copying result_idx_in_level to a specific index in result[]
#      14 # is not supported by ONNX tracing yet.
#      15 # _onnx_merge_levels() is an implementation supported by ONNX
#      16 # that merges the levels to the right indices
#      17 @torch.jit.unused
#      18 def _onnx_merge_levels(levels: Tensor, unmerged_results: list[Tensor]) -> Tensor:
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\ops\roi_align.py:7
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\__init__.py:13
#       1 """
#       2 TorchDynamo is a Python-level JIT compiler designed to make unmodified PyTorch programs faster.
#       3 TorchDynamo hooks into the frame evaluation API in CPython (PEP 523) to dynamically modify Python
#    (...)
#       8 seamlessly optimize PyTorch programs, including those using modern Python features.
#       9 """
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\convert_frame.py:53
#      51 from torch._dynamo.callback import CallbackTrigger
#      52 from torch._dynamo.distributed import get_compile_pg
# ---> 53 from torch._dynamo.symbolic_convert import TensorifyState
#      54 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      55 from torch._logging import structured
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\symbolic_convert.py:52
#      50 import torch
#      51 import torch._logging
# ---> 52 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      53 from torch._guards import tracing, TracingContext
#      54 from torch._logging.structured import dump_file
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\exc.py:41
#      38 import torch._guards
#      40 from . import config
# ---> 41 from .utils import counters
#      44 if TYPE_CHECKING:
#      45     import types
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\_dynamo\utils.py:69
#      67 import torch
#      68 import torch._functorch.config
# ---> 69 import torch.fx.experimental.symbolic_shapes
#      70 import torch.utils._pytree as pytree
#      71 from torch import fx
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\fx\experimental\symbolic_shapes.py:3
#       1 from __future__ import annotations
# ----> 3 import sympy
#       4 from sympy import S
#       6 from torch._prims_common import BoolLike, FloatLike, IntLike
#
# File c:\Users\I N T E L\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\__init__.py:23
#      19 del sys
#      22 try:
# ---> 23     import mpmath
#      24 except ImportError:
#      25     raise ImportError("SymPy now depends on mpmath as an external library. "
#      26     "See https://docs.sympy.org/latest/install.html#mpmath for more information.")
#
# ValueError: source code string cannot contain null bytes

# %%
DEVICE = "cpu"
print("Using device:", DEVICE)

# %%
CKPLUS_ROOT = r"C:\Users\I N T E L\Desktop\FER_Evaluation\CK +"   
VGG_MODEL_PATH = r"C:\Users\I N T E L\Desktop\FER_Evaluation\FER_VGG19\best.pth"       
RESNET_MODEL_PATH = r"C:\Users\I N T E L\Desktop\FER_Evaluation\FER_ResNet18\best.pth" 

NUM_CLASSES = 7
BATCH_SIZE = 32
IMG_SIZE = 224

# %%
emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]

label_to_idx = {
    "anger": 0,
    "disgust": 1,
    "fear": 2,
    "joy": 3,
    "sadness": 4,
    "surprise": 5,
    "neutral": 6
}

folder_mapping = {
    "anger": "anger",
    "disgust": "disgust",
    "fear": "fear",
    "happy": "joy",
    "happiness": "joy",
    "joy": "joy",
    "sadness": "sadness",
    "surprise": "surprise"
}

# %%
class CKPlusDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.samples = []
        self.transform = transform

        for folder in os.listdir(root_dir):
            folder_path = os.path.join(root_dir, folder)

            if not os.path.isdir(folder_path):
                continue

            folder_lower = folder.lower().strip()

            if folder_lower == "contempt":
                print("Skipping contempt class")
                continue

            if folder_lower not in folder_mapping:
                print(f"Skipping unknown folder: {folder}")
                continue

            mapped_label = folder_mapping[folder_lower]
            label_idx = label_to_idx[mapped_label]

            for fname in os.listdir(folder_path):
                if fname.lower().endswith((".png", ".jpg", ".jpeg", ".bmp")):
                    img_path = os.path.join(folder_path, fname)
                    self.samples.append((img_path, label_idx))

        print(f"Loaded {len(self.samples)} CK+ images")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
eval_tf = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485]*3, [0.229]*3)
])

# %%
ck_dataset = CKPlusDataset(CKPLUS_ROOT, transform=eval_tf)
ck_loader = DataLoader(ck_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

print("Number of CK+ samples:", len(ck_dataset))

# %%
def get_model(name):
    if name == "VGG19":
        model = models.vgg19(weights=None)
        model.classifier[6] = nn.Linear(4096, NUM_CLASSES)

    elif name == "ResNet18":
        model = models.resnet18(weights=None)
        model.fc = nn.Linear(model.fc.in_features, NUM_CLASSES)

    else:
        raise ValueError("Unknown model name")

    return model.to(DEVICE)

# %%
def load_trained_model(model_name, model_path):
    model = get_model(model_name)
    state_dict = torch.load(model_path, map_location=DEVICE)
    model.load_state_dict(state_dict)
    model.eval()
    return model

# %%
def evaluate_model(model, loader, model_name):
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = accuracy_score(all_labels, all_preds)

    print(f"\n===== {model_name} on CK+ =====")
    print(f"Accuracy: {acc:.4f}\n")

    ck_class_names = ["anger", "disgust", "fear", "joy", "sadness", "surprise"]

    print(classification_report(
        all_labels,
        all_preds,
        labels=[0,1,2,3,4,5],
        target_names=ck_class_names,
        digits=4,
        zero_division=0
    ))

    cm = confusion_matrix(all_labels, all_preds, labels=[0,1,2,3,4,5])

    plt.figure(figsize=(8,6))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=ck_class_names,
        yticklabels=ck_class_names
    )
    plt.title(f"{model_name} - CK+ Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.tight_layout()
    plt.show()

    return acc, all_labels, all_preds

# %%
vgg_model = load_trained_model("VGG19", VGG_MODEL_PATH)
resnet_model = load_trained_model("ResNet18", RESNET_MODEL_PATH)

print("Both models loaded successfully.")

# %%
vgg_acc, vgg_labels, vgg_preds = evaluate_model(vgg_model, ck_loader, "VGG19")

# %%
resnet_acc, resnet_labels, resnet_preds = evaluate_model(resnet_model, ck_loader, "ResNet18")

# %%
print("\n===== Final CK+ Comparison =====")
print(f"VGG19 Accuracy   : {vgg_acc:.4f}")
print(f"ResNet18 Accuracy: {resnet_acc:.4f}")

if vgg_acc > resnet_acc:
    print("VGG19 generalizes better on CK+")
elif resnet_acc > vgg_acc:
    print("ResNet18 generalizes better on CK+")
else:
    print("Both models perform equally on CK+")

# %%
model_names = ["VGG19", "ResNet18"]
accuracies = [vgg_acc, resnet_acc]

plt.figure(figsize=(6,4))
bars = plt.bar(model_names, accuracies)
plt.ylabel("CK+ Accuracy")
plt.title("Cross-Dataset Evaluation on CK+")

for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
             f"{acc:.4f}", ha="center")

plt.ylim(0, 1)
plt.show()
